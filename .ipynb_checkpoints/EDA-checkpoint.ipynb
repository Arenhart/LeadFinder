# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

# %%
market = pd.read_csv('estaticos_market.csv')
market.drop('Unnamed: 0', axis=1, inplace=True)

# multiple tables shouldn't have redundant data, so only company ids are kept from portifolio
companies = [pd.read_csv('estaticos_portfolio1.csv')['id'],
            pd.read_csv('estaticos_portfolio2.csv')['id'],
            pd.read_csv('estaticos_portfolio3.csv')['id']]


print(market.info())
for comp in companies:
    print(comp.size)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462298 entries, 0 to 462297
# Columns: 181 entries, id to qt_filiais
# dtypes: bool(9), float64(144), int64(1), object(27)
# memory usage: 610.6+ MB
# None
# 555
# 566
# 265

# %%
# Como existem muitas colunas, podemos remover aquelas com um número elevado de observações faltantes.
for col in market.columns:
    if market[col].isna().sum()/market[col].size >= 0.9:
        market.drop(col, axis=1, inplace=True)

# %%
#inspect object columns
obj_df = market.select_dtypes(exclude = 'number')
#print(obj_df.head())
for col in obj_df.columns:
    market[col].fillna(value='NA', inplace=True)
    print(col, obj_df[col].value_counts().size)
# Out:
# id 462298
# fl_matriz 2
# de_natureza_juridica 67
# sg_uf 6
# natureza_juridica_macro 7
# de_ramo 33
# setor 5
# idade_emp_cat 6
# fl_me 2
# fl_sa 2
# fl_epp 1
# fl_mei 2
# fl_ltda 2
# dt_situacao 7334
# fl_st_especial 2
# fl_email 2
# fl_telefone 2
# fl_rm 2
# nm_divisao 87
# nm_segmento 21
# fl_spa 2
# fl_antt 2
# fl_veiculo 2
# fl_optante_simples 2
# fl_optante_simei 2
# sg_uf_matriz 27
# de_saude_tributaria 6
# de_saude_rescencia 5
# de_nivel_atividade 4
# fl_simples_irregular 2
# nm_meso_regiao 19
# nm_micro_regiao 73
# fl_passivel_iss 2
# de_faixa_faturamento_estimado 12
# de_faixa_faturamento_estimado_grupo 11

# %% [markdown]
# A maioria das colunas não-numéricas possuem cardinalidade abiaxo de 100, valores relativamete pequenos, mas que sugerem a impossibilidade de usar one-hot encoding. Umas das colunas se destaca com o número de itens (dt_situacao), que provavelmente pode ser descartada para evitar overfitting.

# %%
num_df = market.select_dtypes(include = 'number')

inputer = SimpleImputer(strategy = 'median', verbose=1)
filled_array = inputer.fit_transform(num_df)
num_df = pd.DataFrame(filled_array, columns=num_df.columns, index=num_df.index)

for col in num_df.columns:
    if num_df[col].var() < 0.1:
        num_df.drop(col, axis=1, inplace=True)

# %%
df = pd.concat((obj_df, num_df), axis=1)

# %%
df.set_index(df['id'],inplace=True)
df.drop('id', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 462298 entries, a6984c3ae395090e3bee8ad63c3758b110de096d5d819583a784a113726db849 to 3d43e934e150b86be1e67524f5ba1018b27da9ef25566d9c0607623ae7f25e3a
# Columns: 105 entries, fl_matriz to qt_filiais
# dtypes: bool(9), float64(71), object(25)
# memory usage: 346.1+ MB

# %%
from catboost import CatBoostClassifier
cat = CatBoostClassifier(auto_class_weights='Balanced', silent=False, iterations=200, max_depth = 5)

# %%
def train_classifier(classifier, client_list):
    market_clients = market.set_index('id')
    market_clients['is_client'] = 0
    market_clients.loc[client_list.array, 'is_client'] = 1
    target = market_clients['is_client']
    features = market_clients.drop('is_client', axis=1)
    cat_columns = features.select_dtypes(exclude = 'number').columns
    classifier.fit(features, target, cat_features=cat_columns)
    
train_classifier(cat, companies[1])
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.0485962	total: 704ms	remaining: 2m 20s
# 1:	learn: 0.0129268	total: 1.37s	remaining: 2m 15s
# 2:	learn: 0.0082781	total: 1.84s	remaining: 2m 1s
# 3:	learn: 0.0074256	total: 2.51s	remaining: 2m 3s
# 4:	learn: 0.0073312	total: 2.91s	remaining: 1m 53s
# 5:	learn: 0.0072968	total: 3.6s	remaining: 1m 56s
# 6:	learn: 0.0072298	total: 4.24s	remaining: 1m 56s
# 7:	learn: 0.0072297	total: 5.01s	remaining: 2m
# 8:	learn: 0.0072296	total: 5.86s	remaining: 2m 4s
# 9:	learn: 0.0072296	total: 6.67s	remaining: 2m 6s
# 10:	learn: 0.0072296	total: 7.52s	remaining: 2m 9s
# 11:	learn: 0.0072295	total: 8.3s	remaining: 2m 9s
# 12:	learn: 0.0072295	total: 9.12s	remaining: 2m 11s
# 13:	learn: 0.0072295	total: 9.81s	remaining: 2m 10s
# 14:	learn: 0.0072295	total: 10.6s	remaining: 2m 10s
# 15:	learn: 0.0072295	total: 11.4s	remaining: 2m 11s
# 16:	learn: 0.0072295	total: 12.1s	remaining: 2m 10s
# 17:	learn: 0.0071787	total: 12.9s	remaining: 2m 10s
# 18:	learn: 0.0071787	total: 13.6s	remaining: 2m 9s
# 19:	learn: 0.0071787	total: 14.3s	remaining: 2m 8s
# 20:	learn: 0.0071787	total: 15.2s	remaining: 2m 9s
# 21:	learn: 0.0071787	total: 15.8s	remaining: 2m 7s
# 22:	learn: 0.0070981	total: 16.7s	remaining: 2m 8s
# 23:	learn: 0.0070933	total: 17.4s	remaining: 2m 7s
# 24:	learn: 0.0070933	total: 18s	remaining: 2m 6s
# 25:	learn: 0.0070915	total: 18.7s	remaining: 2m 5s
# 26:	learn: 0.0070914	total: 19.6s	remaining: 2m 5s
# 27:	learn: 0.0070914	total: 20.1s	remaining: 2m 3s
# 28:	learn: 0.0070914	total: 21s	remaining: 2m 3s
# 29:	learn: 0.0070913	total: 21.9s	remaining: 2m 4s
# 30:	learn: 0.0070913	total: 22.9s	remaining: 2m 4s
# 31:	learn: 0.0070913	total: 23.9s	remaining: 2m 5s
# 32:	learn: 0.0070912	total: 24.7s	remaining: 2m 5s
# 33:	learn: 0.0070911	total: 25.5s	remaining: 2m 4s
# 34:	learn: 0.0070911	total: 26.3s	remaining: 2m 3s
# 35:	learn: 0.0070909	total: 27.2s	remaining: 2m 4s
# 162:	learn: 0.0066256	total: 2m 3s	remaining: 28s
# 163:	learn: 0.0066256	total: 2m 4s	remaining: 27.3s
# 164:	learn: 0.0066256	total: 2m 5s	remaining: 26.5s
# 165:	learn: 0.0066256	total: 2m 5s	remaining: 25.8s
# 166:	learn: 0.0066256	total: 2m 6s	remaining: 25s
# 167:	learn: 0.0066243	total: 2m 7s	remaining: 24.3s
# 168:	learn: 0.0066243	total: 2m 8s	remaining: 23.5s
# 169:	learn: 0.0066243	total: 2m 9s	remaining: 22.8s
# 170:	learn: 0.0066243	total: 2m 9s	remaining: 22s
# 171:	learn: 0.0066242	total: 2m 10s	remaining: 21.3s
# 172:	learn: 0.0066242	total: 2m 11s	remaining: 20.5s
# 173:	learn: 0.0066242	total: 2m 12s	remaining: 19.8s
# 174:	learn: 0.0066241	total: 2m 12s	remaining: 19s
# 175:	learn: 0.0066198	total: 2m 13s	remaining: 18.2s
# 176:	learn: 0.0066198	total: 2m 14s	remaining: 17.5s
# 177:	learn: 0.0066158	total: 2m 15s	remaining: 16.7s
# 178:	learn: 0.0065258	total: 2m 16s	remaining: 16s
# 179:	learn: 0.0065258	total: 2m 17s	remaining: 15.2s
# 180:	learn: 0.0065256	total: 2m 17s	remaining: 14.5s
# 181:	learn: 0.0065255	total: 2m 18s	remaining: 13.7s
# 182:	learn: 0.0065255	total: 2m 19s	remaining: 12.9s
# 183:	learn: 0.0065239	total: 2m 20s	remaining: 12.2s
# 184:	learn: 0.0065237	total: 2m 21s	remaining: 11.4s
# 185:	learn: 0.0065237	total: 2m 21s	remaining: 10.7s
# 186:	learn: 0.0065234	total: 2m 22s	remaining: 9.92s
# 187:	learn: 0.0065234	total: 2m 23s	remaining: 9.16s
# 188:	learn: 0.0065233	total: 2m 24s	remaining: 8.39s
# 189:	learn: 0.0065233	total: 2m 25s	remaining: 7.63s
# 190:	learn: 0.0065232	total: 2m 25s	remaining: 6.87s
# 191:	learn: 0.0065154	total: 2m 26s	remaining: 6.11s
# 192:	learn: 0.0065153	total: 2m 27s	remaining: 5.35s
# 193:	learn: 0.0065152	total: 2m 28s	remaining: 4.58s
# 194:	learn: 0.0065152	total: 2m 28s	remaining: 3.82s
# 195:	learn: 0.0065151	total: 2m 29s	remaining: 3.06s
# 196:	learn: 0.0065151	total: 2m 30s	remaining: 2.29s
# 197:	learn: 0.0065129	total: 2m 31s	remaining: 1.53s
# 198:	learn: 0.0065129	total: 2m 32s	remaining: 765ms
# 199:	learn: 0.0065128	total: 2m 32s	remaining: 0us

# %%
def get_proba(classifier, client_list):
    prospects = market.set_index('id')
    prospects['is_client'] = 0
    prospects.loc[client_list.array, 'is_client'] = 1
    prospects = prospects[prospects['is_client'] == 0]
    prospects.drop('is_client', axis=1, inplace=True)
    #cat_columns = prospects.select_dtypes(exclude = 'number').columns
    return classifier.predict_proba(prospects)

proba = get_proba(cat, companies[1])

# %%
sns.distplot(proba[:,1], bins = 3, kde=False)

# %%
(proba[:,1]>0.5).sum()
# Out:
# 870

# %%
cat.get_feature_importance(prettified=True)
# Out:
#                                   Feature Id  Importances
# 0                         idade_empresa_anos    38.643720
# 1                              idade_emp_cat    26.497344
# 2                                  fl_matriz    13.705524
# 3                         fl_optante_simples    12.731978
# 4              de_faixa_faturamento_estimado     5.450961
# 5                      idade_media_coligadas     0.785570
# 6          vl_faturamento_estimado_grupo_aux     0.488636
# 7                vl_faturamento_estimado_aux     0.389896
# 8                       media_meses_servicos     0.364539
# 9                   coligada_mais_nova_ativa     0.335324
# 10                        min_meses_servicos     0.228270
# 11                           fl_passivel_iss     0.133742
# 12                     qt_funcionarios_grupo     0.051043
# 13                   qt_funcionarios_12meses     0.050491
# 14   grau_instrucao_macro_escolaridade_media     0.028945
# 15                              qt_admitidos     0.026186
# 16                       idade_maxima_socios     0.016593
# 17                                   de_ramo     0.015431
# 18                                     total     0.014922
# 19                           qt_coligados_sa     0.011464
# 20                      de_natureza_juridica     0.007915
# 21                       de_saude_tributaria     0.005146
# 22                  media_meses_servicos_all     0.003821
# 23                           nm_micro_regiao     0.003419
# 24       de_faixa_faturamento_estimado_grupo     0.002013
# 25                                fl_veiculo     0.001943
# 26                           qt_funcionarios     0.001186
# 27                               nm_segmento     0.001132
# 28                                     sg_uf     0.000978
# 29                                    fl_spa     0.000511
# ..                                       ...          ...
# 92                           qt_coligados_me     0.000000
# 93                          qt_coligados_mei     0.000000
# 94                         qt_coligados_ltda     0.000000
# 95                          qt_coligados_epp     0.000000
# 96                        qt_coligados_norte     0.000000
# 97                          qt_coligados_sul     0.000000
# 98                       qt_coligados_centro     0.000000
# 99                      qt_coligados_sudeste     0.000000
# 100                    qt_coligados_exterior     0.000000
# 101                         qt_ufs_coligados     0.000000
# 102                     qt_regioes_coligados     0.000000
# 103                   qt_coligados_industria     0.000000
# 104                qt_coligados_agropecuaria     0.000000
# 105                    qt_coligados_comercio     0.000000
# 106                     qt_coligados_serviço     0.000000
# 107                      qt_coligados_ccivil     0.000000
# 108                faturamento_est_coligados     0.000000
# 109            max_faturamento_est_coligados     0.000000
# 110            min_faturamento_est_coligados     0.000000
# 111             faturamento_est_coligados_gp     0.000000
# 112         min_faturamento_est_coligados_gp     0.000000
# 113              qt_coligados_atividade_alto     0.000000
# 114             qt_coligados_atividade_medio     0.000000
# 115             qt_coligados_atividade_baixo     0.000000
# 116          qt_coligados_atividade_mt_baixo     0.000000
# 117           qt_coligados_atividade_inativo     0.000000
# 118                   max_meses_servicos_all     0.000000
# 119                       max_meses_servicos     0.000000
# 120                   tx_crescimento_12meses     0.000000
# 121                               qt_filiais     0.000000
#
# [122 rows x 2 columns]
